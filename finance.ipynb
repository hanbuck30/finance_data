# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('USD/KRW', '2000')
df['Close'].plot()
df.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2003-12-01  1197.300049  1203.500000  1195.000000  1198.400024  1198.400024
# 2003-12-02  1198.099976  1198.500000  1186.199951  1195.000000  1195.000000
# 2003-12-03  1195.000000  1198.400024  1192.500000  1192.500000  1192.500000
# 2003-12-04  1192.599976  1197.900024  1174.800049  1190.099976  1190.099976
# 2003-12-05  1189.400024  1193.800049  1178.599976  1184.699951  1184.699951
# 2003-12-08  1185.900024  1187.800049  1173.000000  1185.599976  1185.599976
# 2003-12-09  1185.800049  1188.099976  1172.099976  1182.699951  1182.699951
# 2003-12-10  1182.500000  1186.400024  1172.300049  1176.400024  1176.400024
# 2003-12-11  1176.300049  1189.699951  1168.800049  1169.900024  1169.900024
# 2003-12-12  1169.599976  1185.599976  1169.300049  1173.199951  1173.199951
#
#             Volume
# Date
# 2003-12-01     0.0
# 2003-12-02     0.0
# 2003-12-03     0.0
# 2003-12-04     0.0
# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('BTC/USD', '2010')
df['Close'].plot()
df.head(10)
#df[['Close']].describe()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 2014-09-23  402.092010  441.557007  396.196991  435.790985  435.790985
# 2014-09-24  435.751007  436.112000  421.131989  423.204987  423.204987
# 2014-09-25  423.156006  423.519989  409.467987  411.574005  411.574005
# 2014-09-26  411.428986  414.937988  400.009003  404.424988  404.424988
#
#                 Volume
# Date
# 2014-09-17  21056800.0
# 2014-09-18  34483200.0
# 2014-09-19  37919700.0
# 2014-09-20  36863600.0
# 2014-09-21  26580100.0
# 2014-09-22  24127600.0
# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('ETH/USD', '2010')
df['Close'].plot()
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-11-09  308.644989  329.451996  307.056000  320.884003  320.884003
# 2017-11-10  320.670990  324.717987  294.541992  299.252991  299.252991
# 2017-11-11  298.585999  319.453003  298.191986  314.681000  314.681000
# 2017-11-12  314.690002  319.153015  298.513000  307.907990  307.907990
# 2017-11-13  307.024994  328.415009  307.024994  316.716003  316.716003
# 2017-11-14  316.763000  340.177002  316.763000  337.631012  337.631012
# 2017-11-15  337.963989  340.911987  329.812988  333.356995  333.356995
# 2017-11-16  333.442993  336.158997  323.605988  330.924011  330.924011
# 2017-11-17  330.166992  334.963989  327.523010  332.394012  332.394012
# 2017-11-18  331.980011  349.615997  327.687012  347.612000  347.612000
#
#                   Volume
# Date
# 2017-11-09  8.932500e+08
# 2017-11-10  8.859860e+08
# 2017-11-11  8.423010e+08
# 2017-11-12  1.613480e+09
# 2017-11-13  1.041890e+09
# ...

# %% [markdown]
# 대형주 위주매매 저만의 기준
#
# 주가(시총 100)
# 거래량(한국거래소)
# 지수
# 환율
# 금리
# 52주 신고가 신저가
# 보조지표는 이평선 5일선 10일선 20일선 60일선 120일선 240일선볼린저 밴드
# 120선 위로 차트
# 60일선 부터 나머지 이평선이 정배열
#
# RSI,MACD,추세선
#
# 신라젠 에이치엘비 ㅛㅅ
#
# 메트릭스튜디오

# %%
import FinanceDataReader as fdr

# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        62600          2    -1100
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       533000          2   -16000
# 2  000660  KR7000660001    SK하이닉스  KOSPI        92000          2     -900
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       799000          2   -10000
# 4  051910  KR7051910008      LG화학  KOSPI       689000          2   -28000
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0        -1.73   62900   63300   62400  10791265  677809979471
# 1        -2.91  540000  548000  529000    334707  179304631000
# 2        -0.97   91400   92700   90900   1691509  155523968551
# 3        -1.24  803000  805000  797000     34197   27346752000
# 4        -3.91  707000  722000  686000    257670  180292789000
#
#             Marcap      Stocks MarketId
# 0  373708387630000  5969782550      STK
# 1  124722000000000   234000000      STK
# ...

# %%
import FinanceDataReader as fdr

df_US = fdr.DataReader('US500',  '2003-01-01', '2023-02-17')
df_US=df_US['Close']#.plot()
df_US=df_US.reset_index()
df_US
# Out:
#            Date        Close
# 0    2003-01-02   909.030029
# 1    2003-01-03   908.590027
# 2    2003-01-06   929.010010
# 3    2003-01-07   922.929993
# 4    2003-01-08   909.929993
# ...         ...          ...
# 5062 2023-02-10  4090.459961
# 5063 2023-02-13  4137.290039
# 5064 2023-02-14  4136.129883
# 5065 2023-02-15  4147.600098
# 5066 2023-02-16  4090.409912
#
# [5067 rows x 2 columns]

# %%
import FinanceDataReader as fdr
import pandas as pd

df = fdr.DataReader('005930', '2003-01-01', '2023-02-17')
#df['Close'].plot()

df=df['Close'].reset_index()
df_US=df_US['Close'].reset_index()
df
# Out:
#            Date  Close
# 0    2003-01-02   6430
# 1    2003-01-03   6880
# 2    2003-01-06   6990
# 3    2003-01-07   6850
# 4    2003-01-08   6800
# ...         ...    ...
# 4975 2023-02-13  62900
# 4976 2023-02-14  63200
# 4977 2023-02-15  62200
# 4978 2023-02-16  63700
# 4979 2023-02-17  62600
#
# [4980 rows x 2 columns]

# %%
for i in range(len(df)):
    b=0
    for j in range(len(df_US)): 
        if df['Date'][i] == df_US['Date'][j]:
            b+=1
    if b ==0:
        df=df.drop(i)
df
# Out:
#            Date  Close
# 0    2003-01-02   6430
# 1    2003-01-03   6880
# 2    2003-01-06   6990
# 3    2003-01-07   6850
# 4    2003-01-08   6800
# ...         ...    ...
# 4974 2023-02-10  62800
# 4975 2023-02-13  62900
# 4976 2023-02-14  63200
# 4977 2023-02-15  62200
# 4978 2023-02-16  63700
#
# [4825 rows x 2 columns]

# %%
for i in range(len(df_US)):
    b=0
    for j in range(len(df)): 
        if df_US['Date'][i] == df['Date'][j]:
            b+=1
    if b ==0:
        df_US=df_US.drop(i)
df_US
# Out:
#            Date        Close
# 0    2003-01-02   909.030029
# 1    2003-01-03   908.590027
# 2    2003-01-06   929.010010
# 3    2003-01-07   922.929993
# 4    2003-01-08   909.929993
# ...         ...          ...
# 5062 2023-02-10  4090.459961
# 5063 2023-02-13  4137.290039
# 5064 2023-02-14  4136.129883
# 5065 2023-02-15  4147.600098
# 5066 2023-02-16  4090.409912
#
# [4825 rows x 2 columns]

# %%
df=df.reset_index()
df
df_US=df_US.reset_index()
df_US
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-cbb43e6f9fe1> in <module>
#       1 df=df.reset_index()
#       2 df
# ----> 3 df_US=df_US.reset_index()
#       4 df_US
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    5797                     )
#    5798
# -> 5799                 new_obj.insert(0, name, level_values)
#    5800
#    5801         new_obj.index = new_index
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
# ...

# %%
df_Us=df_US.drop(columns=['Date','index','level_0'])
df=df.drop(columns=['level_0','index'])
df_Us
# Out:
#             Close
# 0      909.030029
# 1      908.590027
# 2      929.010010
# 3      922.929993
# 4      909.929993
# ...           ...
# 4820  4090.459961
# 4821  4137.290039
# 4822  4136.129883
# 4823  4147.600098
# 4824  4090.409912
#
# [4825 rows x 1 columns]

# %%
all=pd.concat([df,df_Us],axis=1)
all.columns=['Date','naver','nsp']
all
# Out:
#            Date  naver          nsp
# 0    2003-01-02   6430   909.030029
# 1    2003-01-03   6880   908.590027
# 2    2003-01-06   6990   929.010010
# 3    2003-01-07   6850   922.929993
# 4    2003-01-08   6800   909.929993
# ...         ...    ...          ...
# 4820 2023-02-10  62800  4090.459961
# 4821 2023-02-13  62900  4137.290039
# 4822 2023-02-14  63200  4136.129883
# 4823 2023-02-15  62200  4147.600098
# 4824 2023-02-16  63700  4090.409912
#
# [4825 rows x 3 columns]
