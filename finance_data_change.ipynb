# %% [markdown]
# <a href="https://colab.research.google.com/github/hanbuck30/finance_data/blob/main/finance_data_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U finance-datareader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('DJI', '1990')
df['Close'].plot()
df.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1992-01-02  3152.100098  3172.629883  3139.310059  3172.399902  3172.399902
# 1992-01-03  3172.399902  3210.639893  3165.919922  3201.500000  3201.500000
# 1992-01-06  3201.500000  3213.330078  3191.860107  3200.100098  3200.100098
# 1992-01-07  3200.100098  3210.199951  3184.479980  3204.800049  3204.800049
# 1992-01-08  3204.800049  3229.199951  3185.820068  3203.899902  3203.899902
# 1992-01-09  3203.899902  3228.310059  3192.750000  3209.500000  3209.500000
# 1992-01-10  3209.500000  3217.129883  3185.379883  3199.500000  3199.500000
# 1992-01-13  3199.500000  3201.250000  3179.110107  3185.600098  3185.600098
# 1992-01-14  3185.600098  3248.879883  3182.919922  3246.199951  3246.199951
# 1992-01-15  3246.199951  3263.419922  3232.110107  3258.500000  3258.500000
#
#               Volume
# Date
# 1992-01-02  23550000
# 1992-01-03  23620000
# 1992-01-06  27280000
# 1992-01-07  25510000
# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('IXIC', '1990')
df['Close'].plot()
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1990-01-02  452.899994  459.299988  452.700012  459.299988  459.299988
# 1990-01-03  461.100006  461.600006  460.000000  460.899994  460.899994
# 1990-01-04  460.399994  460.799988  456.899994  459.399994  459.399994
# 1990-01-05  457.899994  459.399994  457.799988  458.200012  458.200012
# 1990-01-08  457.100006  458.700012  456.500000  458.700012  458.700012
# 1990-01-09  459.200012  459.600006  456.600006  456.799988  456.799988
# 1990-01-10  455.100006  456.299988  450.600006  450.700012  450.700012
# 1990-01-11  451.700012  452.500000  448.799988  448.899994  448.899994
# 1990-01-12  442.700012  446.600006  439.299988  439.700012  439.700012
# 1990-01-15  438.200012  439.399994  436.399994  436.600006  436.600006
#
#                Volume
# Date
# 1990-01-02  110720000
# 1990-01-03  152660000
# 1990-01-04  147950000
# 1990-01-05  137230000
# 1990-01-08  115500000
# 1990-01-09  131130000
# ...

# %%
import FinanceDataReader as fdr

df_US = fdr.DataReader('US500',  '2004-01-01', '2023-02-17')
df_US=df_US['Close']#.plot()
df_US=df_US.reset_index()
df_US
# Out:
#            Date        Close
# 0    2004-01-02  1108.479980
# 1    2004-01-05  1122.219971
# 2    2004-01-06  1123.670044
# 3    2004-01-07  1126.329956
# 4    2004-01-08  1131.920044
# ...         ...          ...
# 4810 2023-02-10  4090.459961
# 4811 2023-02-13  4137.290039
# 4812 2023-02-14  4136.129883
# 4813 2023-02-15  4147.600098
# 4814 2023-02-16  4090.409912
#
# [4815 rows x 2 columns]

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('KS11', '1990')
df['Close'].plot()
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1996-12-11  705.989990  709.479980  704.429993  704.679993  704.679993
# 1996-12-12  705.109985  706.010010  688.739990  689.380005  689.380005
# 1996-12-13  690.440002  695.719971  677.640015  689.070007  689.070007
# 1996-12-16  686.969971  686.969971  667.710022  673.919983  673.919983
# 1996-12-17  675.349976  680.090027  660.390015  663.349976  663.349976
# 1996-12-18  662.070007  671.429993  655.469971  661.390015  661.390015
# 1996-12-19  668.130005  690.969971  668.130005  690.969971  690.969971
# 1996-12-20  695.330017  703.510010  692.469971  700.869995  700.869995
# 1996-12-23  691.979980  697.119995  684.809998  684.809998  684.809998
# 1996-12-24  683.109985  687.059998  677.559998  677.760010  677.760010
#
#              Volume
# Date
# 1996-12-11  28000.0
# 1996-12-12  25900.0
# 1996-12-13  26500.0
# 1996-12-16  22800.0
# 1996-12-17  31600.0
# 1996-12-18  31500.0
# 1996-12-19  30400.0
# ...

# %%
import FinanceDataReader as fdr

df_kr = fdr.DataReader('USD/KRW', '2003-12-31', '2023-02-16')
df_kr
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2003-12-31  1194.900024  1198.300049  1189.900024  1189.900024  1189.900024
# 2004-01-01  1191.500000  1192.599976  1181.500000  1181.599976  1181.599976
# 2004-01-02  1181.699951  1195.800049  1180.400024  1195.800049  1195.800049
# 2004-01-05  1190.400024  1193.800049  1178.599976  1178.900024  1178.900024
# 2004-01-06  1179.000000  1189.699951  1172.699951  1189.400024  1189.400024
# ...                 ...          ...          ...          ...          ...
# 2023-02-13  1266.869995  1279.040039  1266.979980  1266.869995  1266.869995
# 2023-02-14  1272.939941  1274.040039  1258.060059  1272.939941  1272.939941
# 2023-02-15  1272.250000  1288.140015  1271.619995  1272.250000  1272.250000
# 2023-02-16  1283.719971  1294.770020  1278.680054  1283.719971  1283.719971
# 2023-02-17  1288.959961  1303.459961  1288.939941  1288.959961  1288.959961
#
#             Volume
# Date
# 2003-12-31     0.0
# ...

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('BTC/USD', '2010')
df['Close'].plot()
df.head(10)
#df[['Close']].describe()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  457.334015
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  424.440002
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  394.795990
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  408.903992
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  398.821014
# 2014-09-22  399.100006  406.915985  397.130005  402.152008  402.152008
# 2014-09-23  402.092010  441.557007  396.196991  435.790985  435.790985
# 2014-09-24  435.751007  436.112000  421.131989  423.204987  423.204987
# 2014-09-25  423.156006  423.519989  409.467987  411.574005  411.574005
# 2014-09-26  411.428986  414.937988  400.009003  404.424988  404.424988
#
#                 Volume
# Date
# 2014-09-17  21056800.0
# 2014-09-18  34483200.0
# 2014-09-19  37919700.0
# 2014-09-20  36863600.0
# 2014-09-21  26580100.0
# 2014-09-22  24127600.0
# ...

# %%
df = fdr.DataReader('035420', '2004-01-01', '2023-02-17')
df=df.reset_index()
df_date=df['Date']
df_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-af1dc2f3e172> in <module>
# ----> 1 df = fdr.DataReader('035420', '2004-01-01', '2023-02-17')
#       2 df=df.reset_index()
#       3 df_date=df['Date']
#       4 df_date
#
# NameError: name 'fdr' is not defined

# %% [markdown]
# 대형주 위주매매 저만의 기준
#
# 주가(시총 100)
# 거래량(한국거래소)
# 지수
# 환율
# 금리
# 52주 신고가 신저가
# 보조지표는 이평선 5일선 10일선 20일선 60일선 120일선 240일선볼린저 밴드
# 120선 위로 차트
# 60일선 부터 나머지 이평선이 정배열
#
# RSI,MACD,추세선
#
# 신라젠 에이치엘비 ㅛㅅ
#
# 메트릭스튜디오

# %%
import FinanceDataReader as fdr

# 한국거래소 상장종목 전체
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        62600          2    -1100
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       533000          2   -16000
# 2  000660  KR7000660001    SK하이닉스  KOSPI        92000          2     -900
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       799000          2   -10000
# 4  051910  KR7051910008      LG화학  KOSPI       689000          2   -28000
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0        -1.73   62900   63300   62400  10791265  677809979471
# 1        -2.91  540000  548000  529000    334707  179304631000
# 2        -0.97   91400   92700   90900   1691509  155523968551
# 3        -1.24  803000  805000  797000     34197   27346752000
# 4        -3.91  707000  722000  686000    257670  180292789000
#
#             Marcap      Stocks MarketId
# 0  373708387630000  5969782550      STK
# 1  124722000000000   234000000      STK
# ...

# %%
import FinanceDataReader as fdr

df_US = fdr.DataReader('US500',  '2003-01-01', '2023-02-17')
df_US=df_US.reset_index()
df_US
# Out:
#            Date         Open         High          Low        Close  \
# 0    2003-01-02   879.820007   909.030029   879.820007   909.030029
# 1    2003-01-03   909.030029   911.250000   903.070007   908.590027
# 2    2003-01-06   908.590027   931.770020   908.590027   929.010010
# 3    2003-01-07   929.010010   930.809998   919.929993   922.929993
# 4    2003-01-08   922.929993   922.929993   908.320007   909.929993
# ...         ...          ...          ...          ...          ...
# 5062 2023-02-10  4068.919922  4094.360107  4060.790039  4090.459961
# 5063 2023-02-13  4096.620117  4138.899902  4092.669922  4137.290039
# 5064 2023-02-14  4126.700195  4159.770020  4095.010010  4136.129883
# 5065 2023-02-15  4119.500000  4148.109863  4103.979980  4147.600098
# 5066 2023-02-16  4114.750000  4136.540039  4089.489990  4090.409912
#
#         Adj Close      Volume
# 0      909.030029  1229200000
# 1      908.590027  1130800000
# 2      929.010010  1435900000
# ...

# %%
import FinanceDataReader as fdr
import pandas as pd

df = fdr.DataReader('035420', '2004-01-01', '2023-02-17')
df_US = fdr.DataReader('US500',  '2004-01-01', '2023-02-17')
df_v = fdr.DataReader('035420', '2003-12-30', '2023-02-16')
df_kr = fdr.DataReader('USD/KRW', '2003-12-30', '2023-02-16')
df=df.reset_index()
df_US=df_US.reset_index()
df
# Out:
#            Date    Open    High     Low   Close   Volume    Change
# 0    2004-01-02    7340    7345    7198    7246   137026 -0.002066
# 1    2004-01-05    7276    7287    7145    7261   116504  0.002070
# 2    2004-01-06    7376    7539    7271    7277   194191  0.002204
# 3    2004-01-07    7335    7430    7199    7199   139545 -0.010719
# 4    2004-01-08    7256    7319    6920    7047   222165 -0.021114
# ...         ...     ...     ...     ...     ...      ...       ...
# 4728 2023-02-13  231000  231000  220500  223000  1308899 -0.030435
# 4729 2023-02-14  226500  228500  223000  224000   745937  0.004484
# 4730 2023-02-15  224500  224500  215000  215500  1424562 -0.037946
# 4731 2023-02-16  218000  222500  218000  220500   959443  0.023202
# 4732 2023-02-17  216000  219000  212000  215500   904481 -0.022676
#
# [4733 rows x 7 columns]

# %%
df_v=df_v[['Volume']]#.reset_index()
#df_v=df_v.drop(columns=['index'])
#df_v.columns=['forward_vol']
df_v=df_v.reset_index()
#df_v=df_v.drop(columns=['index'])
df_v
# Out:
#            Date   Volume
# 0    2003-12-30   202909
# 1    2004-01-02   137026
# 2    2004-01-05   116504
# 3    2004-01-06   194191
# 4    2004-01-07   139545
# ...         ...      ...
# 4728 2023-02-10  1412939
# 4729 2023-02-13  1308899
# 4730 2023-02-14   745937
# 4731 2023-02-15  1424562
# 4732 2023-02-16   959443
#
# [4733 rows x 2 columns]

# %%
df_kr=df_kr[['Close']].reset_index()
#df_kr=df_kr.drop(columns=['index'])
#df_kr.columns=['forward_kr']
df_kr
# Out:
#            Date        Close
# 0    2003-12-30  1194.800049
# 1    2003-12-31  1189.900024
# 2    2004-01-01  1181.599976
# 3    2004-01-02  1195.800049
# 4    2004-01-05  1178.900024
# ...         ...          ...
# 4988 2023-02-10  1264.550049
# 4989 2023-02-13  1266.869995
# 4990 2023-02-14  1272.939941
# 4991 2023-02-15  1272.250000
# 4992 2023-02-16  1283.719971
#
# [4993 rows x 2 columns]

# %%
for i in range(len(df_kr)):
    b=0
    for j in range(len(df_v)): 
        if df_kr['Date'][i] == df_v['Date'][j]:
            b+=1
    if b ==0:
        df_kr=df_kr.drop(i)
df_kr
# Out:
#            Date        Close
# 0    2003-12-30  1194.800049
# 3    2004-01-02  1195.800049
# 4    2004-01-05  1178.900024
# 5    2004-01-06  1189.400024
# 6    2004-01-07  1176.800049
# ...         ...          ...
# 4988 2023-02-10  1264.550049
# 4989 2023-02-13  1266.869995
# 4990 2023-02-14  1272.939941
# 4991 2023-02-15  1272.250000
# 4992 2023-02-16  1283.719971
#
# [4733 rows x 2 columns]

# %%
df_kr=df_kr.drop(columns=['Date'])
df_kr.columns=['forward_kr']

# %%
df_v=df_v.drop(columns=['Date'])
df_v=pd.DataFrame(df_v)
df_v
# Out:
#        Volume
# 0      202909
# 1      137026
# 2      116504
# 3      194191
# 4      139545
# ...       ...
# 4728  1412939
# 4729  1308899
# 4730   745937
# 4731  1424562
# 4732   959443
#
# [4733 rows x 1 columns]

# %%
df_kr=pd.DataFrame(df_kr)
df_kr
# Out:
#        forward_kr
# 0     1194.800049
# 1     1195.800049
# 2     1178.900024
# 3     1189.400024
# 4     1176.800049
# ...           ...
# 4728  1264.550049
# 4729  1266.869995
# 4730  1272.939941
# 4731  1272.250000
# 4732  1283.719971
#
# [4733 rows x 1 columns]

# %%
df_date
# Out:
# 0      2004-01-02
# 1      2004-01-05
# 2      2004-01-06
# 3      2004-01-07
# 4      2004-01-08
#           ...
# 4728   2023-02-13
# 4729   2023-02-14
# 4730   2023-02-15
# 4731   2023-02-16
# 4732   2023-02-17
# Name: Date, Length: 4733, dtype: datetime64[ns]

# %%
df_d=pd.concat([df_date,df_v,df_kr],axis=1)
df_d
# Out:
#            Date   Volume   forward_kr
# 0    2004-01-02   202909  1194.800049
# 1    2004-01-05   137026  1195.800049
# 2    2004-01-06   116504  1178.900024
# 3    2004-01-07   194191  1189.400024
# 4    2004-01-08   139545  1176.800049
# ...         ...      ...          ...
# 4728 2023-02-13  1412939  1264.550049
# 4729 2023-02-14  1308899  1266.869995
# 4730 2023-02-15   745937  1272.939941
# 4731 2023-02-16  1424562  1272.250000
# 4732 2023-02-17   959443  1283.719971
#
# [4733 rows x 3 columns]

# %%
for i in range(len(df_d)):
    b=0
    for j in range(len(df_US)): 
        if df_d['Date'][i] == df_US['Date'][j]:
            b+=1
    if b ==0:
        df_d=df_d.drop(i)
df_d
# Out:
#            Date   Volume   forward_kr
# 0    2004-01-02   202909  1194.800049
# 1    2004-01-05   137026  1195.800049
# 2    2004-01-06   116504  1178.900024
# 3    2004-01-07   194191  1189.400024
# 4    2004-01-08   139545  1176.800049
# ...         ...      ...          ...
# 4727 2023-02-10  1575905  1260.469971
# 4728 2023-02-13  1412939  1264.550049
# 4729 2023-02-14  1308899  1266.869995
# 4730 2023-02-15   745937  1272.939941
# 4731 2023-02-16  1424562  1272.250000
#
# [4585 rows x 3 columns]

# %%
df_d=df_d.reset_index()
df_d=df_d.drop(columns=['index'])
df_d
# Out:
#            Date   Volume   forward_kr
# 0    2004-01-02   202909  1194.800049
# 1    2004-01-05   137026  1195.800049
# 2    2004-01-06   116504  1178.900024
# 3    2004-01-07   194191  1189.400024
# 4    2004-01-08   139545  1176.800049
# ...         ...      ...          ...
# 4580 2023-02-10  1575905  1260.469971
# 4581 2023-02-13  1412939  1264.550049
# 4582 2023-02-14  1308899  1266.869995
# 4583 2023-02-15   745937  1272.939941
# 4584 2023-02-16  1424562  1272.250000
#
# [4585 rows x 3 columns]

# %%
for i in range(len(df_US)):
    b=0
    for j in range(len(df_d)): 
        if df_US['Date'][i] == df_d['Date'][j]:
            b+=1
    if b ==0:
        df_US=df_US.drop(i)
df_US
# Out:
#            Date         Open         High          Low        Close  \
# 0    2004-01-02  1111.920044  1118.849976  1105.079956  1108.479980
# 1    2004-01-05  1108.479980  1122.219971  1108.479980  1122.219971
# 2    2004-01-06  1122.219971  1124.459961  1118.439941  1123.670044
# 3    2004-01-07  1123.670044  1126.329956  1116.449951  1126.329956
# 4    2004-01-08  1126.329956  1131.920044  1124.910034  1131.920044
# ...         ...          ...          ...          ...          ...
# 4810 2023-02-10  4068.919922  4094.360107  4060.790039  4090.459961
# 4811 2023-02-13  4096.620117  4138.899902  4092.669922  4137.290039
# 4812 2023-02-14  4126.700195  4159.770020  4095.010010  4136.129883
# 4813 2023-02-15  4119.500000  4148.109863  4103.979980  4147.600098
# 4814 2023-02-16  4114.750000  4136.540039  4089.489990  4090.409912
#
#         Adj Close      Volume
# 0     1108.479980  1153200000
# 1     1122.219971  1578200000
# 2     1123.670044  1494500000
# ...

# %%
df_US=df_US.reset_index()
df_US=df_US.drop(columns=['index'])
df_US
# Out:
#            Date         Open         High          Low        Close  \
# 0    2004-01-02  1111.920044  1118.849976  1105.079956  1108.479980
# 1    2004-01-05  1108.479980  1122.219971  1108.479980  1122.219971
# 2    2004-01-06  1122.219971  1124.459961  1118.439941  1123.670044
# 3    2004-01-07  1123.670044  1126.329956  1116.449951  1126.329956
# 4    2004-01-08  1126.329956  1131.920044  1124.910034  1131.920044
# ...         ...          ...          ...          ...          ...
# 4580 2023-02-10  4068.919922  4094.360107  4060.790039  4090.459961
# 4581 2023-02-13  4096.620117  4138.899902  4092.669922  4137.290039
# 4582 2023-02-14  4126.700195  4159.770020  4095.010010  4136.129883
# 4583 2023-02-15  4119.500000  4148.109863  4103.979980  4147.600098
# 4584 2023-02-16  4114.750000  4136.540039  4089.489990  4090.409912
#
#         Adj Close      Volume
# 0     1108.479980  1153200000
# 1     1122.219971  1578200000
# 2     1123.670044  1494500000
# ...

# %%
df_na = fdr.DataReader('IXIC', '2004-01-01', '2023-02-17')
df_na
# Out:
#                     Open          High           Low         Close  \
# Date
# 2004-01-02   2011.079956   2022.369995   1999.770020   2006.680054
# 2004-01-05   2020.780029   2047.359985   2020.780029   2047.359985
# 2004-01-06   2044.550049   2061.540039   2039.630005   2057.370117
# 2004-01-07   2056.750000   2078.090088   2047.020020   2077.679932
# 2004-01-08   2089.600098   2100.250000   2078.050049   2100.250000
# ...                  ...           ...           ...           ...
# 2023-02-10  11714.599609  11775.799805  11630.540039  11718.120117
# 2023-02-13  11759.089844  11910.919922  11719.730469  11891.790039
# 2023-02-14  11808.200195  11999.849609  11760.559570  11960.150391
# 2023-02-15  11905.120117  12071.290039  11876.820313  12070.589844
# 2023-02-16  11896.309570  12040.339844  11853.360352  11855.830078
#
#                Adj Close      Volume
# Date
# 2004-01-02   2006.680054  1666780000
# 2004-01-05   2047.359985  2362910000
# ...

# %%
df_na=df_na.reset_index()
df_na=df_na.drop(columns=['index'])
df_na

# %%
for i in range(len(df_na)):
    b=0
    for j in range(len(df_US)): 
        if df_na['Date'][i] == df_US['Date'][j]:
            b+=1
    if b ==0:
        df_na=df_na.drop(i)
df_na
# Out:
#            Date          Open          High           Low         Close  \
# 0    2004-01-02   2011.079956   2022.369995   1999.770020   2006.680054
# 1    2004-01-05   2020.780029   2047.359985   2020.780029   2047.359985
# 2    2004-01-06   2044.550049   2061.540039   2039.630005   2057.370117
# 3    2004-01-07   2056.750000   2078.090088   2047.020020   2077.679932
# 4    2004-01-08   2089.600098   2100.250000   2078.050049   2100.250000
# ...         ...           ...           ...           ...           ...
# 4810 2023-02-10  11714.599609  11775.799805  11630.540039  11718.120117
# 4811 2023-02-13  11759.089844  11910.919922  11719.730469  11891.790039
# 4812 2023-02-14  11808.200195  11999.849609  11760.559570  11960.150391
# 4813 2023-02-15  11905.120117  12071.290039  11876.820313  12070.589844
# 4814 2023-02-16  11896.309570  12040.339844  11853.360352  11855.830078
#
#          Adj Close      Volume
# 0      2006.680054  1666780000
# 1      2047.359985  2362910000
# ...

# %%
df_na=df_na['Close']
#df_na.columns=['nasdak']
df_na=df_na.reset_index()
df_na=df_na.drop(columns=['index'])
df_na
# Out:
#              Close
# 0      2006.680054
# 1      2047.359985
# 2      2057.370117
# 3      2077.679932
# 4      2100.250000
# ...            ...
# 4580  11718.120117
# 4581  11891.790039
# 4582  11960.150391
# 4583  12070.589844
# 4584  11855.830078
#
# [4585 rows x 1 columns]

# %%
df_US=df_US['Close']
#df_US.columns=['sp']
df_US
# Out:
# 0       1108.479980
# 1       1122.219971
# 2       1123.670044
# 3       1126.329956
# 4       1131.920044
#            ...
# 4580    4090.459961
# 4581    4137.290039
# 4582    4136.129883
# 4583    4147.600098
# 4584    4090.409912
# Name: Close, Length: 4585, dtype: float64

# %%
df_dd=pd.concat([df_d,df_na,df_US],axis=1)
df_dd
# Out:
#            Date   Volume   forward_kr         Close        Close
# 0    2004-01-02   202909  1194.800049   2006.680054  1108.479980
# 1    2004-01-05   137026  1195.800049   2047.359985  1122.219971
# 2    2004-01-06   116504  1178.900024   2057.370117  1123.670044
# 3    2004-01-07   194191  1189.400024   2077.679932  1126.329956
# 4    2004-01-08   139545  1176.800049   2100.250000  1131.920044
# ...         ...      ...          ...           ...          ...
# 4580 2023-02-10  1575905  1260.469971  11718.120117  4090.459961
# 4581 2023-02-13  1412939  1264.550049  11891.790039  4137.290039
# 4582 2023-02-14  1308899  1266.869995  11960.150391  4136.129883
# 4583 2023-02-15   745937  1272.939941  12070.589844  4147.600098
# 4584 2023-02-16  1424562  1272.250000  11855.830078  4090.409912
#
# [4585 rows x 5 columns]

# %%
df_dd.columns=['Date','Volume','forward_kr','nasdak','sp']
df_dd
# Out:
#            Date   Volume   forward_kr        nasdak           sp
# 0    2004-01-02   202909  1194.800049   2006.680054  1108.479980
# 1    2004-01-05   137026  1195.800049   2047.359985  1122.219971
# 2    2004-01-06   116504  1178.900024   2057.370117  1123.670044
# 3    2004-01-07   194191  1189.400024   2077.679932  1126.329956
# 4    2004-01-08   139545  1176.800049   2100.250000  1131.920044
# ...         ...      ...          ...           ...          ...
# 4580 2023-02-10  1575905  1260.469971  11718.120117  4090.459961
# 4581 2023-02-13  1412939  1264.550049  11891.790039  4137.290039
# 4582 2023-02-14  1308899  1266.869995  11960.150391  4136.129883
# 4583 2023-02-15   745937  1272.939941  12070.589844  4147.600098
# 4584 2023-02-16  1424562  1272.250000  11855.830078  4090.409912
#
# [4585 rows x 5 columns]

# %%
for i in range(len(df)):
    b=0
    for j in range(len(df_dd)): 
        if df['Date'][i] == df_dd['Date'][j]:
            b+=1
    if b ==0:
        df=df.drop(i)
df
# Out:
#            Date    Open    High     Low   Close   Volume    Change
# 0    2004-01-02    7340    7345    7198    7246   137026 -0.002066
# 1    2004-01-05    7276    7287    7145    7261   116504  0.002070
# 2    2004-01-06    7376    7539    7271    7277   194191  0.002204
# 3    2004-01-07    7335    7430    7199    7199   139545 -0.010719
# 4    2004-01-08    7256    7319    6920    7047   222165 -0.021114
# ...         ...     ...     ...     ...     ...      ...       ...
# 4727 2023-02-10  226000  230500  222000  230000  1412939  0.000000
# 4728 2023-02-13  231000  231000  220500  223000  1308899 -0.030435
# 4729 2023-02-14  226500  228500  223000  224000   745937  0.004484
# 4730 2023-02-15  224500  224500  215000  215500  1424562 -0.037946
# 4731 2023-02-16  218000  222500  218000  220500   959443  0.023202
#
# [4585 rows x 7 columns]

# %%
target=df['Change']
target
# Out:
# 0         7246
# 1         7261
# 2         7277
# 3         7199
# 4         7047
#          ...
# 4727    230000
# 4728    223000
# 4729    224000
# 4730    215500
# 4731    220500
# Name: Close, Length: 4585, dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_dd.to_csv('value.csv')

# %%
target.to_csv('target.csv')
